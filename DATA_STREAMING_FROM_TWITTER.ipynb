# %% [markdown]
# <a href="https://colab.research.google.com/github/kareemrasheed89/TweetMiner/blob/master/DATA_STREAMING_FROM_TWITTER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STREAMING LIVE TWEET FROM TWITTERVERSE
#
#
# The search word would be cyber-attacks

# %%
#import useful library to query the tweets
import tweepy, datetime
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %%
#Add your keys from Twitter developer account
access_token = "2422777100-wz3s3af1cW1id2S9TyJJNIxpk67JfeYlVITxQjE"
access_token_secret = "qVFnu8Uxn7zOdpqPHrab3q4zQZcLa0K29PN8DsL8XNeTy"
consumer_key = "APSyyCYMUcfRClj6wjLgK7Shz"
consumer_secret = "8VKoNpI2MJmkPBkMImOm1ojZM219r8XI4vNkmoiyvmwW41rJus"

# %%
auth =  tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token,access_token_secret)

# %%
api=tweepy.API(auth)
#api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
Tracker=input('What are we tracking on Twitter?: ')
# Out:
# What are we tracking on Twitter?: cyber attacks

# %%
class MyStreamListener(tweepy.StreamListener):

    def on_data(self, data, track=Tracker):
        with open(Tracker + ".json", "a",encoding="utf-8") as file:
            file.write(data)
            print(data)

    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

myStream.filter(track=[Tracker])
# Out:
# {"created_at":"Tue Oct 27 06:01:06 +0000 2020","id":1320968747130195968,"id_str":"1320968747130195968","text":"French Websites Targeted By Alleged Islamist Cyber Attacks https:\/\/t.co\/6P9iHZz44g via @BreitbartNews","source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":523085134,"id_str":"523085134","name":"Vicky","screen_name":"2tweetaboutit","location":"London, England","url":null,"description":"Call me what you like.I know I hate no race or person of colour\nMy own people are under threat so they are my main concern\n#DemographicsMatter #WhiteLivesMatter","translator_type":"none","protected":false,"verified":false,"followers_count":38016,"friends_count":27820,"listed_count":196,"favourites_count":167990,"statuses_count":259426,"created_at":"Tue M
# ...
